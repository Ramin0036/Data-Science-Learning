# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
import tensorflow as tf
from tensorflow import keras

# %%
data = datasets.load_digits()

# %%
X = data.data / 16
y = data.target

# %%
y = keras.utils.to_categorical(y,num_classes=10)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2)

# %%
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(units=32 , activation='relu' , input_shape=(64,)))
model.add(keras.layers.Dense(units=32 , activation='relu'))
model.add(keras.layers.Dense(units=10 , activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,466 (13.54 KB)
#  Trainable params: 3,466 (13.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt = tf.optimizers.Adam(learning_rate=0.01)
loss = tf.losses.CategoricalCrossentropy()

model.compile(optimizer=opt , loss= loss , metrics= [tf.metrics.CategoricalAccuracy()])

# %%
model.fit(X_train,y_train,epochs=20,batch_size=50 , validation_split=0.2 , verbose=2)
# Out:
# Epoch 1/20
# 23/23 - 1s - 29ms/step - categorical_accuracy: 0.5100 - loss: 1.6118 - val_categorical_accuracy: 0.7812 - val_loss: 0.7717
# Epoch 2/20
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.8721 - loss: 0.4406 - val_categorical_accuracy: 0.8889 - val_loss: 0.3744
# Epoch 3/20
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9295 - loss: 0.2371 - val_categorical_accuracy: 0.9062 - val_loss: 0.2764
# Epoch 4/20
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9426 - loss: 0.1719 - val_categorical_accuracy: 0.9340 - val_loss: 0.2287
# Epoch 5/20
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9504 - loss: 0.1372 - val_categorical_accuracy: 0.9514 - val_loss: 0.1819
# Epoch 6/20
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9661 - loss: 0.0958 - val_categorical_accuracy: 0.9306 - val_loss: 0.2142
# Epoch 7/20
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9756 - loss: 0.0771 - val_categorical_accuracy: 0.9375 - val_loss: 0.1948
# Epoch 8/20
# ...

# %% [markdown]
# We see the overfit problem in model fitting process. Then in next steps we will talking about methods that prevent overfitting.

# %%
acc , loss = model.evaluate(X_test , y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.9694 - loss: 0.0843
