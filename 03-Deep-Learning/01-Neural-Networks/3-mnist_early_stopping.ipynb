# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
import tensorflow as tf
from tensorflow import keras

# %%
data = datasets.load_digits()

# %%
X = data.data / 16
y = data.target

# %%
y = keras.utils.to_categorical(y,num_classes=10)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2)

# %%
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(units=32 , activation='relu' , input_shape=(64,)))
model.add(keras.layers.Dense(units=32 , activation='relu'))
model.add(keras.layers.Dense(units=10 , activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,466 (13.54 KB)
#  Trainable params: 3,466 (13.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt = tf.optimizers.Adam(learning_rate=0.01)
loss = tf.losses.CategoricalCrossentropy()

model.compile(optimizer=opt , loss= loss , metrics= [tf.metrics.CategoricalAccuracy()])

# %% [markdown]
# One of the methods prevent the overfit with the patience we set for it.

# %%
# early_stopping
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss' , patience=5 ,restore_best_weights= True)

# %%
model.fit(X_train,y_train,epochs=100 ,batch_size=50 , validation_split=0.2 , verbose=2 , callbacks=early_stopping )
# Out:
# Epoch 1/100
# 23/23 - 1s - 29ms/step - categorical_accuracy: 0.5587 - loss: 1.5237 - val_categorical_accuracy: 0.8472 - val_loss: 0.6223
# Epoch 2/100
# 23/23 - 0s - 5ms/step - categorical_accuracy: 0.8860 - loss: 0.3852 - val_categorical_accuracy: 0.9201 - val_loss: 0.2558
# Epoch 3/100
# 23/23 - 0s - 5ms/step - categorical_accuracy: 0.9339 - loss: 0.2141 - val_categorical_accuracy: 0.9410 - val_loss: 0.1845
# Epoch 4/100
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9452 - loss: 0.1649 - val_categorical_accuracy: 0.9514 - val_loss: 0.1852
# Epoch 5/100
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9547 - loss: 0.1476 - val_categorical_accuracy: 0.9549 - val_loss: 0.1512
# Epoch 6/100
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9721 - loss: 0.1037 - val_categorical_accuracy: 0.9653 - val_loss: 0.1356
# Epoch 7/100
# 23/23 - 0s - 4ms/step - categorical_accuracy: 0.9721 - loss: 0.0865 - val_categorical_accuracy: 0.9444 - val_loss: 0.1381
# Epoch 8/100
# ...

# %% [markdown]
# We have no more overfit problem.

# %%
acc , loss = model.evaluate(X_test , y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.9694 - loss: 0.0944
